# %% [markdown]
# # Aprendizaje de Máquina I - Trabajo Práctico Final

# %% [markdown]
# ## 1. Introducción y motivación
#
# - **Fuente de información de evaluación**: Utilizaremos el dataset [Airline Passsenger Satisfaction](https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction). Este dataset ya tiene el split hecho, en train y test, y comprende respuestas de la encuesta sobre la satisfaccion de pasajeros utilizando la aerolinea.
#
# - **Objetivo**: Predecir el nivel de satisfacción de los pasajeros, con una variable objetivo (target) que puede tomar dos clases: satisfied y neutral or dissatisfied..
#
# - **Problema de negocio**: Las aerolineas enfrentan el desafío de identificar tempranamente a los pasajeros con mayor probabilidad de insatisfacción, que son quienes impactan directamente en la fidelizacion y reputacion de la marca, tanto presente, como futura. Contar con una herramienta predictiva que pueda mejorar las posiblidades de tomar desiciones anticipadas o simplemente implementar acciones correctivas que impidan reclamos y perdida de futuros clientes, sería de gran valor para el negocio.
#
# - **Enfoque**: Para abordar este problema utilizaremos técnicas de análisis de datos y machine learning para construir un modelo predictivo que resuelva un problema de clasificación binaria. Este modelo será validado y ajustado para asegurar su rendimiento y capacidad de generalización.
#
# ### Librerias utilizadas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import optuna as optuna

# %% [markdown]
# ## 2. Análisis expoloratorio inicial (EDA)
#
# ### Importamos el dataset de test y train y se llevo a cabo un **análisis exploratorio de los datos (EDA)**, con el objetivo de entender su estructura y realción entre las variables. Se analizó y obtuvimos algunas consideraciones:
#
# **Tratamiento de Valores Faltantes**: El dataset presenta un porcentaje bajo de valores faltantes (~0,3%). Dado que parece estar MUY por debajo de umbrales comunmente aceptados, evaluamos la posibilidad de eliminarlos o imputar por media o mediana. Finalmente se eliminan.
#
# **Variable objetivo**: Dado que probaremos varios modelos de clasificación, se decide agregar una columna de target numérica, que definiremos como **satisfaction_num** que representa el nivel de satisfacción del pasajero: **{'neutral or dissatisfied': 0, 'satisfied': 1}**.
#
# **Distribucion de la Variable objetivo (Balance)**: Dividimos la variable **satisfaction** en dos clases:
# - **nuetral o dissatisfied**
# - **satisfied**
#
# Notamos un nivel razonable de equilibrio en la distribución general, sin un desbalance grande entre clases.
#
# **Análisis de satisfacción por variable categórica**: Lo analizamos:
# - Tipo de Cliente (customer_type): segun vimos, el tipo de cliente es una variable relevante para predecir la satisfacción.
# - Tipo de Viaje (type_of_travel): el tipo de viaje puede influir significativamente en la percepción del servicio.
# - Clase (class): según respuestas por clase, vemos que es importante la clase del vuelo como predictor.
#
#
#  🔗  [EDA Completo](eda.ipynb)

# %% [markdown]
# ## 3. Limpieza y preparación de modelos
#
# ### Luego de llevar adelante el Análisis Exploratorio **(EDA)** sobre el dataset, se procedio a limpieza y preparación de datos que incluyó los siguientes pasos:
# - Se realizó una inspección inicial de las variables categóricas para indetificar sus valores únicos y validar la consistencia de las categorías.
# - Se aplicó **one-hot encoding** sobre las variables categóricas, transformándolas en variables binarias (0/1).
# - Se definió la variable categórica **satisfation_satisfied** y se separaron los features del target.
# - Se identificaron las variables numéricas originales y se excluyeron las variables dummy del proceso de escalado.
# - Se separaron por tipo de escalado, unas columnas se escalarán con **StandardScaler** y el resto con **MinMaxScaler**
#
#
#
#
# 🔗  [Preparacion de distintos modelos ](modeltesting.ipynb)

# %% [markdown]
# ## 4. Entrenamiento de Modelos
#
# - Luego de preparar los datos y entrenar los modelos, se utilizo el **best_threshold (0.51374)** obtenido, que sirvió para mejorar el equilibrio entre aciertos y errores en la clasificación de la satisfaccion de los pasajeros.
#
# - Los modelos fueron evaluados utilizando métricas como accurancy, F1-weighted, recall y presicion, lo que permitió comparar su desempeño y seleccionar el modelo con mejores resultados.
#
#
# 🔗  [Entrenamiento de modelos](models.ipynb)

# %% [markdown]
# ## 4. Conclusiones

# %% [markdown]
# Comparación de performance por modelo
#
# | Modelo                   | Accuracy   | F1-weighted   | Recall clase 1 | Precision clase 1 |
# |--------------------------|------------|---------------|----------------|-------------------|
# | Regresión  Logistica      | 0.827      | 0.826         | 0.769          | 0.824             |
# | KNN                      | 0.913      | 0.913         | 0.886          | 0.912             |
# | Random Forest            | 0.963      | 0.963         | 0.941          | 0.974             |
# | XGBoost                  | 0.959      | 0.959         | 0.944          | 0.962             |

# %% [markdown]
# #### Resultados de Modelos en graficos visuales
#
# La comparación de modelos por métricas con **barplot**, utilizando las principales métricas de evaluación, nos permite visualizar de forma clara cuáles son los modelos que presentan mejores resultados generales.
#
# ![Comparacion de metricas](Compraracion-metricas.jpeg)
# <br>
# <br>
# <br>
#
# Este gráfico tipo **Heatmap** nos permite ver de manera resumida el desempeño de los modelos evaluados, facilitando la comparacion de metricas e identificando con facilidad el modelo con mejor rendimiento global.
#
# ![Comparacion de metricas](Heatmap.jpeg)
# <br>
# <br>
# <br>
#
# Comprarción de Metricas utilizando el grafico **Loolipo**, nos permite visualizar de forma clara las diferencias de rendimiento entre los modelos para cada métrica, reforzando la comparación entre ellos.
#
# ![Comparacion de metricas](Lollipop.jpeg)
# <br>
# <br>
# <br>
#
# -  🔗  [Graficos comparativos ](graphs.ipynb)
#
# <br>
# <br>
#
#
# ### CONSIDERACIONES FINALES
#
# | Modelo                   | Accuracy   |
# |--------------------------|------------|
# | Random Forest            | 0.963      |
# | XGBoost                  | 0.959      |
# | KNN                      | 0.913      |
# | Regresión  Logistica      | 0.827      |
#
# <br>
# <br>
# - Evaluamos distintos modelos de clasificación para predecir la satisfacción de los pasajeros.
#
# - Random Forest obtuvo el mejor desempeño global, con un Accuracy de 96.3 y un F1-score ponderado de 0.963, superando los valores de XGBoost, KNN y Regresión Logistica.
#
# - El modelo presenta un bajo número de Falsos positvo y un recall alto para la clase "satisfied", lo que nos muestra que tiene alta capacidad para identificar pasajeros satisfechos.
#
# - Los modelos mas simples como Regresión Logistica, muestran un rendimiento significativamente menor, lo que nos muestra la necesidad de modelos lineales para estos problemas con cierto nivel de complejidad.
# <br>
# <br>
